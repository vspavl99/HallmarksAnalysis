# %%
import pandas as pd
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv('../Data/Classification/CleanedData/city_year.csv')

# %%
dataframe['year'].value_counts()
# Out:
# 1932    17
# 1901    16
# 1909    11
# 1902    10
# 1921    10
#         ..
# 1839     1
# 1841     1
# 1849     1
# 1850     1
# 1741     1
# Name: year, Length: 158, dtype: int64

# %%
for _, row in dataframe[dataframe['year'] == 1932].iterrows():
    image = cv2.imread(os.path.join('../Data/Classification/CleanedData/images', row['ImageName']))
    if image is None:
        print(row['ImageName'])

    plt.imshow(image)
    plt.title(row['ImageName'])
    plt.show()

# %%
# !pip install pytesseract
# Out:
# ...
# WARNING: You are using pip version 20.3.3; however, version 21.1 is available.
# You should consider upgrading via the 'c:\users\vpavl\appdata\local\programs\python\python39\python.exe -m pip install --upgrade pip' command.

# %%
import pytesseract

# %%
image = cv2.imread(
    os.path.join('../Data/',
                 '2.png'
                 )
)
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
text = pytesseract.image_to_string(image)
print(text)
# Out:
# Fanteieiteh)

# %%
# get grayscale image
def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# noise removal
def remove_noise(image):
    return cv2.medianBlur(image,5)

#thresholding
def thresholding(image):
    # threshold the image, setting all foreground pixels to
    # 255 and all background pixels to 0
    return cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]

image = cv2.imread(
    os.path.join('../Data/',
                 '1.png'
                 )
)

gray = get_grayscale(image)
plt.imshow(gray)
plt.show()
thresh = thresholding(gray)
plt.imshow(thresh)
plt.show()
rnoise = remove_noise(gray)

plt.imshow(rnoise)

plt.show()

# %%
text = pytesseract.image_to_string(rnoise)
text
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-082beefa277e> in <module>
# ----> 1 text = pytesseract.image_to_string(rnoise)
#       2 text
#       3
#
# NameError: name 'pytesseract' is not defined
